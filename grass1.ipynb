# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshu2374/data-science-45-days/blob/main/grass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Vanshu2374/grass/main/student-data%20set.json"
df = pd.read_json(url)
# filter 1
df[df["english"] == 95]

# filter 2
df[df["maths"] < 60]

# filter 3
df[df["physics"] <= 56]

# multiples
df[(df["maths"] > 90)&(df["english"] > 90)]

df[(df["maths"] > 90) & (df["english"] > 90) & (df["gender"] == "male")]
# Out:
# Empty DataFrame
# Columns: [name, gender, physics, maths, english]
# Index: []

# %%
# sorting
import pandas as pd
url = "https://raw.githubusercontent.com/Vanshu2374/grass/main/student-data%20set.json"
df = pd.read_json(url)
# by default ascending
df.sort_values("english")

# descending
df.sort_values("english",ascending=False)

# by default ascending method
df.sort_values(by=["english"],ascending=False)

# multiple cols sort
df.sort_values(by=['english','maths'],ascending=[False,True])

#lowecase name
df['name'] = df['name'].str.lower()
df.sort_values("name")
# Out:
#        name  gender  physics  maths  english
# 0      arun    Male       88     87       78
# 8    dinesh    Male       56     45       67
# 10    gowri  Female      100    100      100
# 9      hema  Female       71     90       23
# 13  jenifer  Female       67     88       90
# 7   kavitha  Female       78     71       67
# 2   moorthy    Male       89     90       70
# 12  murugan    Male       34     89       78
# 5     priya  Female       56     46       78
# 3      raja    Male       30     25       40
# 1    rajesh    Male       96    100       95
# 11      ram    Male       78     55       47
# 6    sundar    Male       12     67       67
# 4      usha  Female       67     45       78

# %%
# operations
import pandas as pd
url = "https://raw.githubusercontent.com/Vanshu2374/grass/main/student-data%20set.json"
df = pd.read_json(url)

# add columns total = py + maths + english
df['total'] = df['english'] + df['maths'] + df['physics']
df

# add row
df.loc[14] = ["vanshika",'Female',50,80,80,210]
df

# delete column
df.drop("total",axis=1)

# delete row
df.drop(14,axis=0)

# update column
df["physics"] = df["physics"] + 5
df

# update row
df.loc[14,"maths"] = 100
df
# Out:
#         name  gender  physics  maths  english  total
# 0       arun    Male       93     87       78    253
# 1     rajesh    Male      101    100       95    291
# 2    moorthy    Male       94     90       70    249
# 3       raja    Male       35     25       40     95
# 4       usha  Female       72     45       78    190
# 5      priya  Female       61     46       78    180
# 6     Sundar    Male       17     67       67    146
# 7    Kavitha  Female       83     71       67    216
# 8     Dinesh    Male       61     45       67    168
# 9       Hema  Female       76     90       23    184
# 10     Gowri  Female      105    100      100    300
# 11       Ram    Male       83     55       47    180
# 12   Murugan    Male       39     89       78    201
# 13   Jenifer  Female       72     88       90    245
# 14  vanshika  Female       55    100       80    210

# %%
#df.drop([6,7,8,9,10,11,12,13,14],inplace=True)
df
df['doj'] = ['2025-01-01','2025-02-02','2025-01-01','2025-02-02','2025-01-01','2025-02-02']
df
# Out:
#       name  gender  physics  maths  english  total         dob         doj
# 0     arun    Male       88     87       78    253  2025-01-01  2025-01-01
# 1   rajesh    Male       96    100       95    291  2025-02-02  2025-02-02
# 2  moorthy    Male       89     90       70    249  2025-01-01  2025-01-01
# 3     raja    Male       30     25       40     95  2025-02-02  2025-02-02
# 4     usha  Female       67     45       78    190  2025-01-01  2025-01-01
# 5    priya  Female       56     46       78    180  2025-02-02  2025-02-02

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file2.json"
df = pd.read_json(url)
df['doj'] = ['2025-01-10','2025-02-10','2025-03-10','2025-04-10','2025-05-10',]
df['doj'].dtype

# convert string to date
df['doj'] = pd.to_datetime(df['doj'])
df['doj'].dtype

# date operation
df['doj'].dt.year
df['doj'].dt.month
df['doj'].dt.day
df['doj'].dt.day_name()

# 20 days
df['doj'] + pd.to_timedelta(20,unit='D')
# Out:
# 0   2025-01-30
# 1   2025-03-02
# 2   2025-03-30
# 3   2025-04-30
# 4   2025-05-30
# Name: doj, dtype: datetime64[ns]

# %%
from numpy import average
import pandas as pd
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file2.json"
df = pd.read_json(url)

df.isnull()
# sum
df.isnull().sum()

# drop null values by row
df.dropna()

# drop null values by cols
df.dropna(axis=1)

# fill by zeros
df.fillna(0)

# fill by 100
df.fillna(100)

# roll no -> 200 | marks -> 100 -> fillna
df.fillna({"roll no":200,"marks":100},inplace=True)
df

# marks -> mean | nan fill with average
mm = df['marks'].mean()
df["marks"] = df['marks'].fillna(mm)
df
# Out:
#        name    roll no  marks
# 0   dheeraj      123.0   10.0
# 1     kunal      200.0   20.0
# 2  abhishek    12345.0  100.0
# 3   praveen    12356.0   40.0
# 4    anjali  1234567.0   50.0

# %%
# aggregation
import pandas as pd
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file2.json"
df = pd.read_json(url)
# manually
df['marks'].sum()
df['marks'].mean()
df['marks'].min()
df['marks'].max()

# using aggregation
df['marks'].agg(["sum","mean","min","max"])
# Out:
# sum     120.0
# mean     30.0
# min      10.0
# max      50.0
# Name: marks, dtype: float64

# %%
# concatenate
import pandas as pd
url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file2.json"
df = pd.read_json(url)
df1 = pd.read_json(url)
pd.concat([df,df1]) # row

pd.concat([df,df1],axis=1)

# name -> col2 -> abhishek -> vanshika
pd.concat([df,df1],axis=1)
# Out:
#        name    roll no  marks      name    roll no  marks
# 0   dheeraj      123.0   10.0   dheeraj      123.0   10.0
# 1     kunal        NaN   20.0     kunal        NaN   20.0
# 2  abhishek    12345.0    NaN  abhishek    12345.0    NaN
# 3   praveen    12356.0   40.0   praveen    12356.0   40.0
# 4    anjali  1234567.0   50.0    anjali  1234567.0   50.0

# %%
import matplotlib.pyplot as plt
score = [10,20,30,40]
over = [1,2,3,4]
plt.plot(score,over)
plt.show()
