# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshu2374/data-science-45-days/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# fuction
def hello():
  print("hello function is working")

hello()

#example
def hello1(a): # a as a parameter
  print(a)
hello1(100) # 100 as a argument
# Out:
# hello function is working
# 100

# %%
#example
def add(a=0,b=1): # default parameter value
  print(a+b)
add(10,5)
add()

#example
def power(a,b):
  print(a**b)

power(5,2)
power(2,5)
power(b=5,a=2) # 32
# Out:
# 15
# 1
# 25
# 32
# 32

# %%
#example
def student(*a):
  print(a)
  print(type(a))
  print(a[0])

student(1,2,3,4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>
# 1
# [10, 20, 30, 40, 50]

# %%
#example
def marks(b): #parameter
 for i in range(len(b)):
  print(b[i])

marks([10,20,30,40,50])

#example
def address(a):
  for i in range(len(a)):
   for j in range(len(a[i])):
    print(a[i][j])



address(["hello","vanshika"])
# Out:
# 10
# 20
# 30
# 40
# 50
# h
# e
# l
# l
# o
# v
# a
# n
# s
# h
# i
# k
# a

# %%
#example
def sum(a,b):
  return a+b

sum(10,20)
# Out:
# 30

# %%
#lambda functions
add = lambda x: x
print(add(100))

sum = lambda x,y: x+y
print(sum(10,20))

a = lambda x:x
print(a([10,20,30,40]))
# Out:
# 100
# 30
# [10, 20, 30, 40]

# %%
#example
a = lambda *x: [i for i in x]
print(a([10,20,30]))
# Out:
# [[10, 20, 30]]

# %%
#list comprehension
print([i for i in range(5)])

#example
l = [10,20,30,40,50]
print([l[i] for i in range(len(l))])
# Out:
# [0, 1, 2, 3, 4]
# [10, 20, 30, 40, 50]

# %%
#example
l = [10,20[30,40,50,60]]
print([l[-1][i] for i in range(len(l[-1]))])
# Out:
# <>:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# /tmp/ipykernel_6166/483892483.py:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   l = [10,20[30,40,50,60]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6166/483892483.py in <cell line: 0>()
#       1 #example
# ----> 2 l = [10,20[30,40,50,60]]
#       3 print([l[-1][i] for i in range(len(l[-1]))])
#
# TypeError: 'int' object is not subscriptable

# %%
#list
l = [10,20,30,40,50]
print(l)
print(l[0])
print(l[-1])
print(l[-2])

#example of append
l = ["hello","vanshika","python"]
l.append("for arya mains")
print(l)
print(l[0])
print(l[-1])

#example of insert
l = [True,False,10,20]
l.insert(1,100)
print(l)
# Out:
# [10, 20, 30, 40, 50]
# 10
# 50
# 40
# ['hello', 'vanshika', 'python', 'for arya mains']
# hello
# for arya mains
# [True, 100, False, 10, 20]

# %%
#question
l = [10,20,30,{"name":"vanshika","address":["jaipur","kukas","home town","friend house"]}]
print(l[3]['address'])
print(l[-1]['address'])
for i in l[3]['address']:
  print(i)

#example
l = [10,20,30,[40,50,[60,70,80]]]
for i in range(len(l[3])-1):
  print(l[3][i])
# Out:
# ['jaipur', 'kukas', 'home town', 'friend house']
# ['jaipur', 'kukas', 'home town', 'friend house']
# jaipur
# kukas
# home town
# friend house
# 40
# 50

# %%
#dictionary
d = {"name":"hello","age":20}

print(d.keys())
print(d.values())

for i in d.keys():
  print("key=" , 1)
  print("values=",d[i])
# Out:
# dict_keys(['name', 'age'])
# dict_values(['hello', 20])
# key= 1
# values= hello
# key= 1
# values= 20
